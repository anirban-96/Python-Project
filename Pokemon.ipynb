# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use('ggplot')

# %% [markdown]
# ### Reading Data from CSV

# %%
df=pd.read_csv('pokemon_data.csv')

# %% [markdown]
# ### First 5 Rows

# %%
df.head()
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False

# %% [markdown]
# ### Represent data in PairPlot using Seaborn Library

# %%
sns.pairplot(df)
# Out:
# <__array_function__ internals>:200: RuntimeWarning: Converting input from bool to <class 'numpy.uint8'> for compatibility.
# C:\Users\MM0724\AppData\Roaming\Python\Python311\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# ### Review of the DataFrame

# %%
df
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# ...

# %% [markdown]
# ### Total number of records in DataFrame

# %%
df.shape
# Out:
# (800, 12)

# %% [markdown]
# ### Display the Column Name within the DataFrame

# %%
df.columns
# Out:
# Index(['#', 'Name', 'Type 1', 'Type 2', 'HP', 'Attack', 'Defense', 'Sp. Atk',
#        'Sp. Def', 'Speed', 'Generation', 'Legendary'],
#       dtype='object')

# %% [markdown]
# ### Adding a Calculated Column

# %%
df['Total']=df['HP']+df['Attack']+df['Defense']+df['Sp. Atk']+df['Sp. Def']+df['Speed']

# %%
df.head()
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary  Total
# 0       65     45           1      False    318
# 1       80     60           1      False    405
# 2      100     80           1      False    525
# 3      120     80           1      False    625
# 4       50     65           1      False    309

# %% [markdown]
# ### Counting number of duplicates present

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ### Representing count of Type 1 Pokemon in Bar Graph

# %%
df['Type 1'].value_counts().plot(kind='barh')
# Out:
# <Axes: ylabel='Type 1'>

# %% [markdown]
# ### Show Name, Type 1, Type 2 column from 2nd to 6th Row

# %%
df.loc[2:6,['Name','Type 1','Type 2']]
# Out:
#                     Name Type 1  Type 2
# 2               Venusaur  Grass  Poison
# 3  VenusaurMega Venusaur  Grass  Poison
# 4             Charmander   Fire     NaN
# 5             Charmeleon   Fire     NaN
# 6              Charizard   Fire  Flying

# %% [markdown]
# ### Find count of NAN (NULL) values within each column

# %%
df.isna().sum()
# Out:
# #               0
# Name            0
# Type 1          0
# Type 2        386
# HP              0
# Attack          0
# Defense         0
# Sp. Atk         0
# Sp. Def         0
# Speed           0
# Generation      0
# Legendary       0
# Total           0
# dtype: int64

# %% [markdown]
# ### Filling NAN (NULL) values with 'N/A'

# %%
df.fillna('N/A')
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     N/A  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary  Total
# 0         65       65     45           1      False    318
# ...

# %% [markdown]
# ### Finding unique values in Type 2 column

# %%
df['Type 2'].unique()
# Out:
# array(['Poison', nan, 'Flying', 'Dragon', 'Ground', 'Fairy', 'Grass',
#        'Fighting', 'Psychic', 'Steel', 'Ice', 'Rock', 'Dark', 'Water',
#        'Electric', 'Fire', 'Ghost', 'Bug', 'Normal'], dtype=object)

# %% [markdown]
# ### Displaying the data type of each column

# %%
df.dtypes
# Out:
# #              int64
# Name          object
# Type 1        object
# Type 2        object
# HP             int64
# Attack         int64
# Defense        int64
# Sp. Atk        int64
# Sp. Def        int64
# Speed          int64
# Generation     int64
# Legendary       bool
# Total          int64
# dtype: object

# %% [markdown]
# ### Shows information related to data type and count of not-null values in DataFrame

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 800 entries, 0 to 799
# Data columns (total 13 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   #           800 non-null    int64
#  1   Name        800 non-null    object
#  2   Type 1      800 non-null    object
#  3   Type 2      414 non-null    object
#  4   HP          800 non-null    int64
#  5   Attack      800 non-null    int64
#  6   Defense     800 non-null    int64
#  7   Sp. Atk     800 non-null    int64
#  8   Sp. Def     800 non-null    int64
#  9   Speed       800 non-null    int64
#  10  Generation  800 non-null    int64
#  11  Legendary   800 non-null    bool
#  12  Total       800 non-null    int64
# dtypes: bool(1), int64(9), object(3)
# memory usage: 75.9+ KB

# %% [markdown]
# ### Shows the Statistical Parameters about all numerical columns

# %%
df.describe()
# Out:
#                 #          HP      Attack     Defense     Sp. Atk     Sp. Def  \
# count  800.000000  800.000000  800.000000  800.000000  800.000000  800.000000
# mean   362.813750   69.258750   79.001250   73.842500   72.820000   71.902500
# std    208.343798   25.534669   32.457366   31.183501   32.722294   27.828916
# min      1.000000    1.000000    5.000000    5.000000   10.000000   20.000000
# 25%    184.750000   50.000000   55.000000   50.000000   49.750000   50.000000
# 50%    364.500000   65.000000   75.000000   70.000000   65.000000   70.000000
# 75%    539.250000   80.000000  100.000000   90.000000   95.000000   90.000000
# max    721.000000  255.000000  190.000000  230.000000  194.000000  230.000000
#
#             Speed  Generation      Total
# count  800.000000   800.00000  800.00000
# mean    68.277500     3.32375  435.10250
# std     29.060474     1.66129  119.96304
# min      5.000000     1.00000  180.00000
# 25%     45.000000     2.00000  330.00000
# ...

# %% [markdown]
# ### Shows the relationship between Attack & Defense using Scatterplot

# %%
sns.scatterplot(data=df,x='Attack',y='Defense', hue='Type 1')
# Out:
# <Axes: xlabel='Attack', ylabel='Defense'>

# %% [markdown]
# ### Storing in a dataframe the Names of Pokemon containing 'Char' and sort by Defense and HP

# %%
charmaner = df.loc[df['Name'].str.contains('Char'),['Name','Speed','HP','Defense']]\
.sort_values(by=['Defense','HP'],ascending=[False,True])

# %%
charmaner.reset_index(drop=True,inplace=True)

# %%
charmaner
# Out:
#                         Name  Speed  HP  Defense
# 0  CharizardMega Charizard X    100  78      111
# 1                  Charizard    100  78       78
# 2  CharizardMega Charizard Y    100  78       78
# 3                 Charmeleon     80  58       58
# 4                 Charmander     65  39       43

# %% [markdown]
# ### Displaying last 4 records

# %%
df.tail(4)
# Out:
#        #                 Name   Type 1 Type 2  HP  Attack  Defense  Sp. Atk  \
# 796  719  DiancieMega Diancie     Rock  Fairy  50     160      110      160
# 797  720  HoopaHoopa Confined  Psychic  Ghost  80     110       60      150
# 798  720   HoopaHoopa Unbound  Psychic   Dark  80     160       60      170
# 799  721            Volcanion     Fire  Water  80     110      120      130
#
#      Sp. Def  Speed  Generation  Legendary  Total
# 796      110    110           6       True    700
# 797      130     70           6       True    600
# 798      130     80           6       True    680
# 799       90     70           6       True    600

# %%
df=df.reset_index(drop=True)

# %%
df
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary  Total
# 0         65       65     45           1      False    318
# ...

# %% [markdown]
# ### Showing Mean Total Value of Type 1 Pokemon in a Bar Graph

# %%
ax=df.groupby('Type 1')['Total'].mean().round(2).sort_values(ascending=False)\
.plot(kind='bar', title='Mean value by Type Pokemon')
ax.set_xlabel('Type 1 POkemon')
ax.set_ylabel('Mean Values')
plt.show()

# %% [markdown]
# ### iat is used in place of iloc to display scaler value only

# %%
df.iat[4,4]
# Out:
# 39

# %%
df.iloc[2:20:2,[2,4,6]]
# Out:
#    Type 1  HP  Defense
# 2   Grass  80       83
# 4    Fire  39       43
# 6    Fire  78       78
# 8    Fire  78       78
# 10  Water  59       80
# 12  Water  79      120
# 14    Bug  50       55
# 16    Bug  40       30
# 18    Bug  65       40

# %%
df.iloc[[3,12,15,21,41,51],[3,5,2,7]]
# Out:
#     Type 2  Attack  Type 1  Sp. Atk
# 3   Poison     100   Grass      122
# 12     NaN     103   Water      135
# 15  Flying      45     Bug       90
# 21  Flying      60  Normal       50
# 41     NaN      70   Fairy       95
# 51   Grass      70     Bug       45

# %% [markdown]
# ### Using iterrows to display all record of a particular column

# %%
for index,row in df.iterrows():
    print(index,row['Name'])
# Out:
# 0 Bulbasaur
# 1 Ivysaur
# 2 Venusaur
# 3 VenusaurMega Venusaur
# 4 Charmander
# 5 Charmeleon
# 6 Charizard
# 7 CharizardMega Charizard X
# 8 CharizardMega Charizard Y
# 9 Squirtle
# 10 Wartortle
# 11 Blastoise
# 12 BlastoiseMega Blastoise
# 13 Caterpie
# 14 Metapod
# 15 Butterfree
# 16 Weedle
# 17 Kakuna
# 18 Beedrill
# 19 BeedrillMega Beedrill
# 20 Pidgey
# 21 Pidgeotto
# 22 Pidgeot
# 23 PidgeotMega Pidgeot
# 24 Rattata
# 25 Raticate
# 26 Spearow
# 27 Fearow
# 28 Ekans
# 29 Arbok
# 30 Pikachu
# 31 Raichu
# 32 Sandshrew
# 33 Sandslash
# 34 Nidoran (Female)
# 35 Nidorina
# 36 Nidoqueen
# 37 Nidoran (Male)
# 38 Nidorino
# 39 Nidoking
# 40 Clefairy
# 41 Clefable
# 42 Vulpix
# 43 Ninetales
# 44 Jigglypuff
# 45 Wigglytuff
# 46 Zubat
# 47 Golbat
# 48 Oddish
# 49 Gloom
# 50 Vileplume
# 51 Paras
# 52 Parasect
# 53 Venonat
# 54 Venomoth
# 55 Diglett
# 56 Dugtrio
# 57 Meowth
# 58 Persian
# 59 Psyduck
# 60 Golduck
# 61 Mankey
# 62 Primeape
# 63 Growlithe
# 64 Arcanine
# 65 Poliwag
# ...

# %% [markdown]
# ### Filter rows by Type 1 as Fire and Type 2 as Flying and display certain columns

# %%
df.loc[(df['Type 1']=='Fire') & (df['Type 2']=='Flying'),['Name','Type 1','Type 2','Total']]
# Out:
#                           Name Type 1  Type 2  Total
# 6                    Charizard   Fire  Flying    534
# 8    CharizardMega Charizard Y   Fire  Flying    634
# 158                    Moltres   Fire  Flying    580
# 270                      Ho-oh   Fire  Flying    680
# 730                Fletchinder   Fire  Flying    382
# 731                 Talonflame   Fire  Flying    499

# %% [markdown]
# ### Adding a column and deleting that column

# %%
df['Faltu']="Rickshaw"

# %%
df.head()
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary  Total     Faltu
# 0       65     45           1      False    318  Rickshaw
# 1       80     60           1      False    405  Rickshaw
# 2      100     80           1      False    525  Rickshaw
# 3      120     80           1      False    625  Rickshaw
# 4       50     65           1      False    309  Rickshaw

# %%
df.drop(columns=['Faltu'],inplace=True)

# %%
df
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary  Total
# 0         65       65     45           1      False    318
# ...

# %% [markdown]
# ### Sorting columns in a customizable way

# %%
cols=list(df.columns)

# %%
cols
# Out:
# ['#',
#  'Name',
#  'Type 1',
#  'Type 2',
#  'HP',
#  'Attack',
#  'Defense',
#  'Sp. Atk',
#  'Sp. Def',
#  'Speed',
#  'Generation',
#  'Legendary',
#  'Total']

# %%
df=df[cols[0:4]+[cols[-1]]+cols[4:12]]

# %%
df.head()
# Out:
#    #                   Name Type 1  Type 2  Total  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison    318    318  45      49       49
# 1  2                Ivysaur  Grass  Poison    405    405  60      62       63
# 2  3               Venusaur  Grass  Poison    525    525  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    625    625  80     100      123
# 4  4             Charmander   Fire     NaN    309    309  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 4       60       50     65           1      False

# %% [markdown]
# ### Saving dataframe into a CSV

# %%
df.to_csv('Pokemon.csv',index=False,sep=';')

# %% [markdown]
# ### Finding number of records which donot have 'Mega' substring in Name Column

# %%
df.loc[~df['Name'].str.contains('Mega'),['Name','Sp. Atk','Sp. Def']].shape
# Out:
# (751, 3)

# %% [markdown]
# ### Importing Regex Module and displaying records containing 'fire' or 'grass' in Type 1 Column

# %%
import re
df.loc[df['Type 1'].str.contains('fire|grass',flags=re.I,regex=True)]
# Out:
#        #                   Name Type 1  Type 2  Total  Total   HP  Attack  \
# 0      1              Bulbasaur  Grass  Poison    318    318   45      49
# 1      2                Ivysaur  Grass  Poison    405    405   60      62
# 2      3               Venusaur  Grass  Poison    525    525   80      82
# 3      3  VenusaurMega Venusaur  Grass  Poison    625    625   80     100
# 4      4             Charmander   Fire     NaN    309    309   39      52
# ..   ...                    ...    ...     ...    ...    ...  ...     ...
# 735  667                 Litleo   Fire  Normal    369    369   62      50
# 736  668                 Pyroar   Fire  Normal    507    507   86      68
# 740  672                 Skiddo  Grass     NaN    350    350   66      65
# 741  673                 Gogoat  Grass     NaN    531    531  123     100
# 799  721              Volcanion   Fire   Water    600    600   80     110
#
#      Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %% [markdown]
# ### Displaying rows that start with 'pi' followed by any character from Name column

# %%
df.loc[df['Name'].str.contains('^pi[a-z]*',flags=re.I,regex=True),['Name','Total','Defense','Attack']]
# Out:
#                     Name  Total  Total  Defense  Attack
# 20                Pidgey    251    251       40      45
# 21             Pidgeotto    349    349       55      60
# 22               Pidgeot    479    479       75      80
# 23   PidgeotMega Pidgeot    579    579       80      80
# 30               Pikachu    320    320       40      55
# 136               Pinsir    500    500      100     125
# 137    PinsirMega Pinsir    600    600      120     155
# 186                Pichu    205    205       15      40
# 219               Pineco    290    290       90      65
# 239            Piloswine    450    450       80     100
# 438               Piplup    314    314       53      51
# 558              Pignite    418    418       55      93
# 578               Pidove    264    264       50      55

# %% [markdown]
# ### Altering Value of Ghost type Pokemon to Guest in Type 2 Column

# %%
df.loc[df['Type 2']=='Ghost','Type 2']='Guest'

# %%
df[df['Type 2']=='Guest']
# Out:
#        #                   Name    Type 1 Type 2  Total  Total   HP  Attack  \
# 316  292               Shedinja       Bug  Guest    236    236    1      90
# 326  302                Sableye      Dark  Guest    380    380   50      75
# 327  302    SableyeMega Sableye      Dark  Guest    480    480   50      85
# 530  478               Froslass       Ice  Guest    480    480   70      80
# 531  479                  Rotom  Electric  Guest    440    440   50      50
# 653  592               Frillish     Water  Guest    335    335   55      40
# 654  593              Jellicent     Water  Guest    480    480  100      60
# 683  622                 Golett    Ground  Guest    303    303   59      74
# 684  623                 Golurk    Ground  Guest    483    483   89     124
# 748  679                Honedge     Steel  Guest    325    325   45      80
# 749  680               Doublade     Steel  Guest    448    448   59     110
# ...

# %% [markdown]
# ### Replacing Guest to Ghost

# %%
df=df['Type 2'].replace('Guest','Ghost')

# %%
df.value_counts()
# Out:
# Type 2
# Flying      97
# Ground      35
# Poison      34
# Psychic     33
# Fighting    26
# Grass       25
# Fairy       23
# Steel       22
# Dark        20
# Dragon      18
# Water       14
# Ghost       14
# Ice         14
# Rock        14
# Fire        12
# Electric     6
# Normal       4
# Bug          3
# Name: count, dtype: int64

# %% [markdown]
# ### Show the mean value of Total, Defense, Attack grouping by Type 1 Pokemon

# %%
df.groupby(['Type 1'])[['Total','Defense','Attack']].mean().sort_values(by='Attack',ascending=False)
# Out:
#                Total     Defense      Attack
# Type 1
# Dragon    550.531250   86.375000  112.125000
# Fighting  416.444444   65.925926   96.777778
# Ground    437.500000   84.843750   95.750000
# Rock      453.750000  100.795455   92.863636
# Steel     487.703704  126.370370   92.703704
# Dark      445.741935   70.225806   88.387097
# Fire      458.076923   67.769231   84.769231
# Flying    485.000000   66.250000   78.750000
# Poison    399.142857   68.821429   74.678571
# Water     430.455357   72.946429   74.151786
# Ghost     439.562500   81.187500   73.781250
# Normal    401.683673   59.846939   73.469388
# Grass     421.142857   70.800000   73.214286
# Ice       433.458333   71.416667   72.750000
# Psychic   475.947368   67.684211   71.456140
# Bug       378.927536   70.724638   70.971014
# Electric  443.409091   66.295455   69.090909
# Fairy     413.176471   65.705882   61.529412

# %% [markdown]
# ### Adding a column called Count with value 1

# %%
df['Count']=1

# %%
df.head()
# Out:
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                Ivysaur  Grass  Poison    405  60      62       63
# 2  3               Venusaur  Grass  Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4             Charmander   Fire     NaN    309  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary  Count
# 0       65       65     45           1      False      1
# 1       80       80     60           1      False      1
# 2      100      100     80           1      False      1
# 3      122      120     80           1      False      1
# 4       60       50     65           1      False      1

# %% [markdown]
# ### Using Count column show the number of Type 2 Pokemon

# %%
df.groupby('Type 2')['Count'].count()
# Out:
# Type 2
# Bug          3
# Dark        20
# Dragon      18
# Electric     6
# Fairy       23
# Fighting    26
# Fire        12
# Flying      97
# Ghost       14
# Grass       25
# Ground      35
# Ice         14
# Normal       4
# Poison      34
# Psychic     33
# Rock        14
# Steel       22
# Water       14
# Name: Count, dtype: int64

# %% [markdown]
# ### Group by using multiple columns

# %%
df.groupby(['Type 1','Type 2'])['Count'].count()
# Out:
# Type 1  Type 2
# Bug     Electric     2
#         Fighting     2
#         Fire         2
#         Flying      14
#         Ghost        1
#                     ..
# Water   Ice          3
#         Poison       3
#         Psychic      5
#         Rock         4
#         Steel        1
# Name: Count, Length: 136, dtype: int64

# %% [markdown]
# ### Adding data in chunks (say: 5 rows each) to dataframe

# %%
for df in pd.read_csv('Modified.csv',chunksize=5):
    print('chunksize')
    print(df)
# Out:
# chunksize
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                Ivysaur  Grass  Poison    405  60      62       63
# 2  3               Venusaur  Grass  Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4             Charmander   Fire     NaN    309  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 4       60       50     65           1      False
# chunksize
#    #                       Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 5  5                 Charmeleon   Fire     NaN    405  58      64       58
# ...

# %% [markdown]
# ### miscellaneous Tasks

# %%
pd.DataFrame({'Name':['Rishi','Vicky','Seema','Maya']})
# Out:
#     Name
# 0  Rishi
# 1  Vicky
# 2  Seema
# 3   Maya

# %%
s=pd.Series([12,13,'ABC','MAN',32,41])

# %%
s
# Out:
# 0     12
# 1     13
# 2    ABC
# 3    MAN
# 4     32
# 5     41
# dtype: object

# %%
s.dtypes
# Out:
# dtype('O')

# %%
dates=pd.date_range('20230901',periods=10)

# %%
dates
# Out:
# DatetimeIndex(['2023-09-01', '2023-09-02', '2023-09-03', '2023-09-04',
#                '2023-09-05', '2023-09-06', '2023-09-07', '2023-09-08',
#                '2023-09-09', '2023-09-10'],
#               dtype='datetime64[ns]', freq='D')

# %%
af=pd.DataFrame(np.random.randn(10,4),index=dates,columns=list("ABCD"))

# %%
af
# Out:
#                    A         B         C         D
# 2023-09-01  0.603054  0.205124  0.587160 -0.652589
# 2023-09-02 -0.340063 -0.150562  0.383440 -0.191466
# 2023-09-03  0.616256  1.383223 -0.439435 -0.728563
# 2023-09-04  0.793304 -0.874262 -0.365199  0.805055
# 2023-09-05 -0.823604  0.174608 -0.709099 -0.456665
# 2023-09-06 -0.270611 -0.220810 -0.755372  0.739506
# 2023-09-07  0.903915  0.798524 -1.399375  0.242545
# 2023-09-08  0.218332 -1.806496  0.935599 -0.092225
# 2023-09-09 -0.031204 -1.471539  0.538798  0.347714
# 2023-09-10  0.767949  1.029405  0.269307  1.475446

# %%
af2= pd.DataFrame({
    'A': 1.0,
    'B': pd.Timestamp('20231002'),
    'C': pd.Series(1,index=list(range(4)),dtype=np.int8),
    'D': np.array([12,15,17,21], dtype=np.float32),
    'E': pd.Categorical(['Run','Fun','Nun','Bun']),
    'F': 'Rea'
}
    )

# %%
af2
# Out:
#      A          B  C     D    E    F
# 0  1.0 2023-10-02  1  12.0  Run  Rea
# 1  1.0 2023-10-02  1  15.0  Fun  Rea
# 2  1.0 2023-10-02  1  17.0  Nun  Rea
# 3  1.0 2023-10-02  1  21.0  Bun  Rea

# %%
af2.dtypes
# Out:
# A           float64
# B    datetime64[ns]
# C              int8
# D           float32
# E          category
# F            object
# dtype: object

# %%
af2.head()
# Out:
#      A          B  C     D    E    F
# 0  1.0 2023-10-02  1  12.0  Run  Rea
# 1  1.0 2023-10-02  1  15.0  Fun  Rea
# 2  1.0 2023-10-02  1  17.0  Nun  Rea
# 3  1.0 2023-10-02  1  21.0  Bun  Rea

# %%
af.tail()
# Out:
#                    A         B         C         D
# 2023-09-06 -0.270611 -0.220810 -0.755372  0.739506
# 2023-09-07  0.903915  0.798524 -1.399375  0.242545
# 2023-09-08  0.218332 -1.806496  0.935599 -0.092225
# 2023-09-09 -0.031204 -1.471539  0.538798  0.347714
# 2023-09-10  0.767949  1.029405  0.269307  1.475446

# %%
af.head()
# Out:
#                    A         B         C         D
# 2023-09-01  0.603054  0.205124  0.587160 -0.652589
# 2023-09-02 -0.340063 -0.150562  0.383440 -0.191466
# 2023-09-03  0.616256  1.383223 -0.439435 -0.728563
# 2023-09-04  0.793304 -0.874262 -0.365199  0.805055
# 2023-09-05 -0.823604  0.174608 -0.709099 -0.456665

# %%
af.index
# Out:
# DatetimeIndex(['2023-09-01', '2023-09-02', '2023-09-03', '2023-09-04',
#                '2023-09-05', '2023-09-06', '2023-09-07', '2023-09-08',
#                '2023-09-09', '2023-09-10'],
#               dtype='datetime64[ns]', freq='D')

# %%
af.columns
# Out:
# Index(['A', 'B', 'C', 'D'], dtype='object')

# %%
af.to_numpy()
# Out:
# array([[ 0.60305414,  0.20512398,  0.58715958, -0.65258899],
#        [-0.34006325, -0.15056199,  0.3834397 , -0.19146626],
#        [ 0.61625557,  1.38322262, -0.43943518, -0.72856293],
#        [ 0.79330403, -0.87426173, -0.36519877,  0.8050551 ],
#        [-0.82360387,  0.17460822, -0.70909858, -0.45666464],
#        [-0.270611  , -0.22081002, -0.75537153,  0.73950555],
#        [ 0.90391523,  0.79852394, -1.39937477,  0.24254508],
#        [ 0.21833155, -1.80649631,  0.93559865, -0.09222461],
#        [-0.03120448, -1.47153897,  0.53879788,  0.34771417],
#        [ 0.76794889,  1.02940519,  0.26930716,  1.47544612]])

# %%
af2.to_numpy()
# Out:
# array([[1.0, Timestamp('2023-10-02 00:00:00'), 1, 12.0, 'Run', 'Rea'],
#        [1.0, Timestamp('2023-10-02 00:00:00'), 1, 15.0, 'Fun', 'Rea'],
#        [1.0, Timestamp('2023-10-02 00:00:00'), 1, 17.0, 'Nun', 'Rea'],
#        [1.0, Timestamp('2023-10-02 00:00:00'), 1, 21.0, 'Bun', 'Rea']],
#       dtype=object)

# %%
af.describe
# Out:
# <bound method NDFrame.describe of                    A         B         C         D
# 2023-09-01  0.603054  0.205124  0.587160 -0.652589
# 2023-09-02 -0.340063 -0.150562  0.383440 -0.191466
# 2023-09-03  0.616256  1.383223 -0.439435 -0.728563
# 2023-09-04  0.793304 -0.874262 -0.365199  0.805055
# 2023-09-05 -0.823604  0.174608 -0.709099 -0.456665
# 2023-09-06 -0.270611 -0.220810 -0.755372  0.739506
# 2023-09-07  0.903915  0.798524 -1.399375  0.242545
# 2023-09-08  0.218332 -1.806496  0.935599 -0.092225
# 2023-09-09 -0.031204 -1.471539  0.538798  0.347714
# 2023-09-10  0.767949  1.029405  0.269307  1.475446>

# %%
af.T
# Out:
#    2023-09-01  2023-09-02  2023-09-03  2023-09-04  2023-09-05  2023-09-06  \
# A    0.603054   -0.340063    0.616256    0.793304   -0.823604   -0.270611
# B    0.205124   -0.150562    1.383223   -0.874262    0.174608   -0.220810
# C    0.587160    0.383440   -0.439435   -0.365199   -0.709099   -0.755372
# D   -0.652589   -0.191466   -0.728563    0.805055   -0.456665    0.739506
#
#    2023-09-07  2023-09-08  2023-09-09  2023-09-10
# A    0.903915    0.218332   -0.031204    0.767949
# B    0.798524   -1.806496   -1.471539    1.029405
# C   -1.399375    0.935599    0.538798    0.269307
# D    0.242545   -0.092225    0.347714    1.475446

# %%
af.sort_index(axis=1,ascending=False)
# Out:
#                    D         C         B         A
# 2023-09-01 -0.652589  0.587160  0.205124  0.603054
# 2023-09-02 -0.191466  0.383440 -0.150562 -0.340063
# 2023-09-03 -0.728563 -0.439435  1.383223  0.616256
# 2023-09-04  0.805055 -0.365199 -0.874262  0.793304
# 2023-09-05 -0.456665 -0.709099  0.174608 -0.823604
# 2023-09-06  0.739506 -0.755372 -0.220810 -0.270611
# 2023-09-07  0.242545 -1.399375  0.798524  0.903915
# 2023-09-08 -0.092225  0.935599 -1.806496  0.218332
# 2023-09-09  0.347714  0.538798 -1.471539 -0.031204
# 2023-09-10  1.475446  0.269307  1.029405  0.767949

# %%
af.sort_values(by='B')
# Out:
#                    A         B         C         D
# 2023-09-08  0.218332 -1.806496  0.935599 -0.092225
# 2023-09-09 -0.031204 -1.471539  0.538798  0.347714
# 2023-09-04  0.793304 -0.874262 -0.365199  0.805055
# 2023-09-06 -0.270611 -0.220810 -0.755372  0.739506
# 2023-09-02 -0.340063 -0.150562  0.383440 -0.191466
# 2023-09-05 -0.823604  0.174608 -0.709099 -0.456665
# 2023-09-01  0.603054  0.205124  0.587160 -0.652589
# 2023-09-07  0.903915  0.798524 -1.399375  0.242545
# 2023-09-10  0.767949  1.029405  0.269307  1.475446
# 2023-09-03  0.616256  1.383223 -0.439435 -0.728563

# %%
af['A']
# Out:
# 2023-09-01    0.603054
# 2023-09-02   -0.340063
# 2023-09-03    0.616256
# 2023-09-04    0.793304
# 2023-09-05   -0.823604
# 2023-09-06   -0.270611
# 2023-09-07    0.903915
# 2023-09-08    0.218332
# 2023-09-09   -0.031204
# 2023-09-10    0.767949
# Freq: D, Name: A, dtype: float64

# %%
af[0:4]
# Out:
#                    A         B         C         D
# 2023-09-01  0.603054  0.205124  0.587160 -0.652589
# 2023-09-02 -0.340063 -0.150562  0.383440 -0.191466
# 2023-09-03  0.616256  1.383223 -0.439435 -0.728563
# 2023-09-04  0.793304 -0.874262 -0.365199  0.805055

# %%
af['20230902':'20230904']
# Out:
#                    A         B         C         D
# 2023-09-02 -0.340063 -0.150562  0.383440 -0.191466
# 2023-09-03  0.616256  1.383223 -0.439435 -0.728563
# 2023-09-04  0.793304 -0.874262 -0.365199  0.805055

# %%
af.loc[af['A']>0,['C','B']]
# Out:
#                    C         B
# 2023-09-01  0.587160  0.205124
# 2023-09-03 -0.439435  1.383223
# 2023-09-04 -0.365199 -0.874262
# 2023-09-07 -1.399375  0.798524
# 2023-09-08  0.935599 -1.806496
# 2023-09-10  0.269307  1.029405
